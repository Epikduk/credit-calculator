# %%
import service

# %% [markdown]
# Чтобы воспользоваться кредитным калькулятором, вам необходимо ввести:
# - дату начала кредита (дд-мм-гггг):

# %%
date = service.validation_date()
print(f'Введенная дата: {date.strftime("%d-%m-%Y")}')
# Out:
# Введенная дата: 03-06-2025

# %% [markdown]
# - годовую ставку (%):

# %%
annual_rate = service.validation_float('Введите годовую ставку: ')
print(f'Введенная годовая ставка: {annual_rate}')
# Out:
# Введенная годовая ставка: 22.0

# %% [markdown]
# - стоимость недвижимости (руб.):

# %%
property_value = service.validation_float('Введите стоимость недвижимости: ')
print(f'Введенная стоимость недвижимости: {property_value}')
# Out:
# Введенная стоимость недвижимости: 10000000.0

# %% [markdown]
# - первоначальный взнос (руб.):

# %%
initial_payment = service.validation_float('Введите первоначальный взнос: ')
print(f'Введенный первоначальный взнос: {initial_payment}')
# Out:
# Введенный первоначальный взнос: 3000000.0

# %% [markdown]
# - срок ипотеки (г.):

# %%
mortgage_term = service.validation_int('Введите срок ипотеки: ')
print(f'Введеный срок ипотеки: {mortgage_term}')
# Out:
# Введеный срок ипотеки: 15

# %% [markdown]
# - вид платежа (аннуитетный или дифференцированный)
#
# Для выбора аннуитетного вида платежа введите: 1
#
# Для выбора дифференцированного вида платежа введите: 2

# %%
user_choice = service.payment_data()
print(f'Выбранный вид платежа: {service.USER_CHOICE[user_choice]}')
# Out:
# Выбранный вид платежа: дифференцированный

# %% [markdown]
# Табличный вариант рассчета:

# %%
service.print_table_or_chart(user_choice, annual_rate, property_value, initial_payment, mortgage_term, date, 'table')
# Out:
# Размер итоговой суммы с учетом первоначального взноса равен 21 614 166.67
# Размер переплаты по кредиту равен 11 614 166.67
# +---------------+------------+----------------+-----------+------------+---------------+
# | Номер платежа |    Дата    | Размер платежа |    Долг   |  Проценты  | Остаток долга |
# +---------------+------------+----------------+-----------+------------+---------------+
# |       1       | 03-06-2025 |   167 222.22   | 38 888.89 | 128 333.33 |  6 961 111.11 |
# |       2       | 03-07-2025 |   166 509.26   | 38 888.89 | 127 620.37 |  6 922 222.22 |
# |       3       | 03-08-2025 |   165 796.30   | 38 888.89 | 126 907.41 |  6 883 333.33 |
# |       4       | 03-09-2025 |   165 083.33   | 38 888.89 | 126 194.44 |  6 844 444.44 |
# |       5       | 03-10-2025 |   164 370.37   | 38 888.89 | 125 481.48 |  6 805 555.56 |
# |       6       | 03-11-2025 |   163 657.41   | 38 888.89 | 124 768.52 |  6 766 666.67 |
# ...

# %% [markdown]
# Графический вариант рассчета:

# %%
service.print_table_or_chart(user_choice, annual_rate, property_value, initial_payment, mortgage_term, date, 'chart')
